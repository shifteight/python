# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, alpha=0.5)
plt.show()

# %%
# %matplotlib inline

# %%
np.rank?

# %% [markdown]
# $\{A_n\}$

# %%
pwd
# Out:
# u'/home/kevin/work/python/quant-econ'

# %%
ls
# Out:
# Untitled.ipynb

# %%
cp '/home/kevin/Downloads/QuantEcon/QuantEcon.py-master/examples/white_noise_plot.py' .

# %%
ls
# Out:
# Untitled.ipynb  white_noise_plot.py

# %%
run white_noise_plot.py

# %%
edit white_noise_plot.py

# %%
edit
# Out:
# IPython will make a temporary file named: /tmp/ipython_edit_ddMU7B/ipython_edit_7nLQIj.py

# %%
# %%file white_noise_plot.py
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0, 1) for i in range(100)]
plot(x, 'b-', label="white noise")
legend()
show()
# Out:
# Writing white_noise_plot.py

# %%
rm white_noise_plot.py

# %%
ls
# Out:
# Untitled.ipynb

# %%
ls
# Out:
# Untitled.ipynb  white_noise_plot.py

# %%
ls
# Out:
# test_program_1.py  Untitled.ipynb  white_noise_plot.py

# %%
run test_program_1.py

# %%
range(4)[1]
# Out:
# 1

# %%
xrange(4)[1]
# Out:
# 1

# %%
run test_program_1.py

# %%
run test_program_2.py

# %%
run test_program_3.py

# %%
ls
# Out:
# python_by_example.ipynb  test_program_2.py  white_noise_plot.py
# test_program_1.py        test_program_3.py

# %%
import fac

# %%
fac.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000L

# %%
run ex_functions.py

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000L

# %%
binomial_rv(10, 0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-8f935d29de0e> in <module>()
# ----> 1 binomial_rv(10, 0.5)
#
# /home/kevin/work/python/quant-econ/ex_functions.py in binomial_rv(n, p)
#       9         v = 0
#      10         for i in range(n):
# ---> 11                 if uniform() < p:
#      12                         v += 1
#      13         return v
#
# TypeError: uniform() takes exactly 3 arguments (1 given)

# %%
reload(ex_functions.py)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-50f88c508e29> in <module>()
# ----> 1 reload(ex_functions.py)
#
# NameError: name 'ex_functions' is not defined

# %%
run ex_functions.py

# %%
binomial_rv(10, 0.5)
# Out:
# 5

# %%
a = []

for i in range(1000):
    v = binomial_rv(10, 0.5)
    a.append(v)
sum(a) / 1000.0
# Out:
# 4.934

# %%
run ex_functions.py

# %%
find_pi(1000000)
# Out:
# 4.0

# %%
run ex_functions.py

# %%
find_pi(100000)
# Out:
# 3.14428

# %%
run ex_functions.py

# %%
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0, 1) for i in range(100)]
plot(x, 'b-', label="white noise")
legend()
show()

# %%
run ex_functions.py

# %%
# Plot with legends
for alpha in [0.0, 0.8, 0.98]:
	plt.plot(generate_ts(200, alpha), label='alpha = ' + str(alpha))
plt.legend()
